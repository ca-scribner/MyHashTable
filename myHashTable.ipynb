# %% [markdown]
# # Summary
#
# Some play with custom HashTable to watch how collisions and access vary with the % utilization of the hash table

# %%
# %load_ext autoreload

# %autoreload 2

# %%
import logging
logging.basicConfig()

import numpy as np
import matplotlib.pyplot as plt

from MyHashTable import MyHashTable

# %%
# logging.getLogger("MyHashTable").setLevel(logging.DEBUG)

# %%
def ht_access_test_setup(ht_settings, utilization):
    """
    Populate a hash table with some data
    """
    n_data = int(ht_settings['n_buckets'] * utilization)
    ht = MyHashTable(**ht_settings)
    for i in range(n_data):
        ht[str(i)] = i
    return ht

def ht_access_test(ht):
    """
    Access every key in the hash table exactly once, returning the average number of collisions per access
    """
    collisions = 0
    for k in ht:
        _ = ht[k]
        collisions += getattr(ht.collision_log[-1], 'collisions')
    
    return collisions / len(ht)

# %%
n_bucketss = [100, 500, 1000, 5000]
results = [None] * len(n_bucketss)
utilizations = np.linspace(0.01, 1.0, 100)

for i, n_buckets in enumerate(n_bucketss):
    ht_settings = dict(n_buckets=n_buckets, auto_resize=False)
    results[i] = np.zeros((len(utilizations), 2))
    for j, utilization in enumerate(utilizations):
        ht = ht_access_test_setup(ht_settings, utilization)
        cl_avg = ht_access_test(ht)
        results[i][j] = (utilization, cl_avg)
# Out:
# DEBUG:MyHashTable:set 0: 0 (start)
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found empty bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=0, collisions=0)
# DEBUG:MyHashTable:set 0: 0 -> bucket 73 (1 / 100 (1.0%))
# DEBUG:MyHashTable:get 0
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found correct bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=1, collisions=0)
# DEBUG:MyHashTable:get 0: 0 from bucket 73
# DEBUG:MyHashTable:set 0: 0 (start)
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found empty bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=0, collisions=0)
# DEBUG:MyHashTable:set 0: 0 -> bucket 73 (1 / 100 (1.0%))
# DEBUG:MyHashTable:set 1: 1 (start)
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found empty bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=1, collisions=0)
# DEBUG:MyHashTable:set 1: 1 -> bucket 92 (2 / 100 (2.0%))
# DEBUG:MyHashTable:get 0
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found correct bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=2, collisions=0)
# DEBUG:MyHashTable:get 0: 0 from bucket 73
# DEBUG:MyHashTable:get 1
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found correct bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=2, collisions=0)
# DEBUG:MyHashTable:get 1: 1 from bucket 92
# DEBUG:MyHashTable:set 0: 0 (start)
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found empty bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=0, collisions=0)
# DEBUG:MyHashTable:set 0: 0 -> bucket 73 (1 / 100 (1.0%))
# DEBUG:MyHashTable:set 1: 1 (start)
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found empty bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=1, collisions=0)
# DEBUG:MyHashTable:set 1: 1 -> bucket 92 (2 / 100 (2.0%))
# DEBUG:MyHashTable:set 2: 2 (start)
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found empty bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=2, collisions=0)
# DEBUG:MyHashTable:set 2: 2 -> bucket 55 (3 / 100 (3.0%))
# DEBUG:MyHashTable:get 2
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found correct bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=3, collisions=0)
# DEBUG:MyHashTable:get 2: 2 from bucket 55
# DEBUG:MyHashTable:get 0
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found correct bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=3, collisions=0)
# DEBUG:MyHashTable:get 0: 0 from bucket 73
# DEBUG:MyHashTable:get 1
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found correct bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=3, collisions=0)
# DEBUG:MyHashTable:get 1: 1 from bucket 92
# DEBUG:MyHashTable:set 0: 0 (start)
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found empty bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=0, collisions=0)
# DEBUG:MyHashTable:set 0: 0 -> bucket 73 (1 / 100 (1.0%))
# DEBUG:MyHashTable:set 1: 1 (start)
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found empty bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=1, collisions=0)
# DEBUG:MyHashTable:set 1: 1 -> bucket 92 (2 / 100 (2.0%))
# DEBUG:MyHashTable:set 2: 2 (start)
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found empty bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=2, collisions=0)
# DEBUG:MyHashTable:set 2: 2 -> bucket 55 (3 / 100 (3.0%))
# DEBUG:MyHashTable:set 3: 3 (start)
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found empty bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=3, collisions=0)
# DEBUG:MyHashTable:set 3: 3 -> bucket 5 (4 / 100 (4.0%))
# DEBUG:MyHashTable:get 3
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found correct bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=4, collisions=0)
# DEBUG:MyHashTable:get 3: 3 from bucket 5
# DEBUG:MyHashTable:get 2
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found correct bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=4, collisions=0)
# DEBUG:MyHashTable:get 2: 2 from bucket 55
# DEBUG:MyHashTable:get 0
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found correct bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=4, collisions=0)
# DEBUG:MyHashTable:get 0: 0 from bucket 73
# DEBUG:MyHashTable:get 1
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found correct bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=4, collisions=0)
# DEBUG:MyHashTable:get 1: 1 from bucket 92
# DEBUG:MyHashTable:set 0: 0 (start)
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found empty bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=0, collisions=0)
# DEBUG:MyHashTable:set 0: 0 -> bucket 73 (1 / 100 (1.0%))
# DEBUG:MyHashTable:set 1: 1 (start)
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found empty bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=1, collisions=0)
# DEBUG:MyHashTable:set 1: 1 -> bucket 92 (2 / 100 (2.0%))
# DEBUG:MyHashTable:set 2: 2 (start)
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found empty bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=2, collisions=0)
# DEBUG:MyHashTable:set 2: 2 -> bucket 55 (3 / 100 (3.0%))
# DEBUG:MyHashTable:set 3: 3 (start)
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found empty bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=3, collisions=0)
# DEBUG:MyHashTable:set 3: 3 -> bucket 5 (4 / 100 (4.0%))
# DEBUG:MyHashTable:set 4: 4 (start)
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found empty bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=4, collisions=0)
# DEBUG:MyHashTable:set 4: 4 -> bucket 29 (5 / 100 (5.0%))
# DEBUG:MyHashTable:get 3
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found correct bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=5, collisions=0)
# DEBUG:MyHashTable:get 3: 3 from bucket 5
# DEBUG:MyHashTable:get 4
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found correct bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=5, collisions=0)
# DEBUG:MyHashTable:get 4: 4 from bucket 29
# DEBUG:MyHashTable:get 2
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found correct bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=5, collisions=0)
# DEBUG:MyHashTable:get 2: 2 from bucket 55
# DEBUG:MyHashTable:get 0
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found correct bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=5, collisions=0)
# DEBUG:MyHashTable:get 0: 0 from bucket 73
# DEBUG:MyHashTable:get 1
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found correct bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=5, collisions=0)
# DEBUG:MyHashTable:get 1: 1 from bucket 92
# DEBUG:MyHashTable:set 0: 0 (start)
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found empty bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=0, collisions=0)
# DEBUG:MyHashTable:set 0: 0 -> bucket 73 (1 / 100 (1.0%))
# DEBUG:MyHashTable:set 1: 1 (start)
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found empty bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=1, collisions=0)
# DEBUG:MyHashTable:set 1: 1 -> bucket 92 (2 / 100 (2.0%))
# DEBUG:MyHashTable:set 2: 2 (start)
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found empty bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=2, collisions=0)
# DEBUG:MyHashTable:set 2: 2 -> bucket 55 (3 / 100 (3.0%))
# DEBUG:MyHashTable:set 3: 3 (start)
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found empty bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=3, collisions=0)
# DEBUG:MyHashTable:set 3: 3 -> bucket 5 (4 / 100 (4.0%))
# DEBUG:MyHashTable:set 4: 4 (start)
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found empty bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=4, collisions=0)
# DEBUG:MyHashTable:set 4: 4 -> bucket 29 (5 / 100 (5.0%))
# DEBUG:MyHashTable:set 5: 5 (start)
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found empty bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=5, collisions=0)
# DEBUG:MyHashTable:set 5: 5 -> bucket 11 (6 / 100 (6.0%))
# DEBUG:MyHashTable:get 3
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found correct bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:get 3: 3 from bucket 5
# DEBUG:MyHashTable:get 5
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found correct bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:get 5: 5 from bucket 11
# DEBUG:MyHashTable:get 4
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found correct bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:get 4: 4 from bucket 29
# DEBUG:MyHashTable:get 2
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found correct bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:get 2: 2 from bucket 55
# DEBUG:MyHashTable:get 0
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found correct bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:get 0: 0 from bucket 73
# DEBUG:MyHashTable:get 1
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found correct bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:get 1: 1 from bucket 92
# DEBUG:MyHashTable:set 0: 0 (start)
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found empty bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=0, collisions=0)
# DEBUG:MyHashTable:set 0: 0 -> bucket 73 (1 / 100 (1.0%))
# DEBUG:MyHashTable:set 1: 1 (start)
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found empty bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=1, collisions=0)
# DEBUG:MyHashTable:set 1: 1 -> bucket 92 (2 / 100 (2.0%))
# DEBUG:MyHashTable:set 2: 2 (start)
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found empty bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=2, collisions=0)
# DEBUG:MyHashTable:set 2: 2 -> bucket 55 (3 / 100 (3.0%))
# DEBUG:MyHashTable:set 3: 3 (start)
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found empty bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=3, collisions=0)
# DEBUG:MyHashTable:set 3: 3 -> bucket 5 (4 / 100 (4.0%))
# DEBUG:MyHashTable:set 4: 4 (start)
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found empty bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=4, collisions=0)
# DEBUG:MyHashTable:set 4: 4 -> bucket 29 (5 / 100 (5.0%))
# DEBUG:MyHashTable:set 5: 5 (start)
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found empty bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=5, collisions=0)
# DEBUG:MyHashTable:set 5: 5 -> bucket 11 (6 / 100 (6.0%))
# DEBUG:MyHashTable:get 3
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found correct bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:get 3: 3 from bucket 5
# DEBUG:MyHashTable:get 5
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found correct bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:get 5: 5 from bucket 11
# DEBUG:MyHashTable:get 4
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found correct bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:get 4: 4 from bucket 29
# DEBUG:MyHashTable:get 2
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found correct bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:get 2: 2 from bucket 55
# DEBUG:MyHashTable:get 0
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found correct bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:get 0: 0 from bucket 73
# DEBUG:MyHashTable:get 1
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found correct bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:get 1: 1 from bucket 92
# DEBUG:MyHashTable:set 0: 0 (start)
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found empty bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=0, collisions=0)
# DEBUG:MyHashTable:set 0: 0 -> bucket 73 (1 / 100 (1.0%))
# DEBUG:MyHashTable:set 1: 1 (start)
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found empty bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=1, collisions=0)
# DEBUG:MyHashTable:set 1: 1 -> bucket 92 (2 / 100 (2.0%))
# DEBUG:MyHashTable:set 2: 2 (start)
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found empty bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=2, collisions=0)
# DEBUG:MyHashTable:set 2: 2 -> bucket 55 (3 / 100 (3.0%))
# DEBUG:MyHashTable:set 3: 3 (start)
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found empty bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=3, collisions=0)
# DEBUG:MyHashTable:set 3: 3 -> bucket 5 (4 / 100 (4.0%))
# DEBUG:MyHashTable:set 4: 4 (start)
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found empty bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=4, collisions=0)
# DEBUG:MyHashTable:set 4: 4 -> bucket 29 (5 / 100 (5.0%))
# DEBUG:MyHashTable:set 5: 5 (start)
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found empty bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=5, collisions=0)
# DEBUG:MyHashTable:set 5: 5 -> bucket 11 (6 / 100 (6.0%))
# DEBUG:MyHashTable:set 6: 6 (start)
# DEBUG:MyHashTable:Looking for key 6 in bucket 65
# DEBUG:MyHashTable:Found empty bucket 65 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:set 6: 6 -> bucket 65 (7 / 100 (7.0%))
# DEBUG:MyHashTable:set 7: 7 (start)
# DEBUG:MyHashTable:Looking for key 7 in bucket 52
# DEBUG:MyHashTable:Found empty bucket 52 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=7, collisions=0)
# DEBUG:MyHashTable:set 7: 7 -> bucket 52 (8 / 100 (8.0%))
# DEBUG:MyHashTable:get 3
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found correct bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=8, collisions=0)
# DEBUG:MyHashTable:get 3: 3 from bucket 5
# DEBUG:MyHashTable:get 5
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found correct bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=8, collisions=0)
# DEBUG:MyHashTable:get 5: 5 from bucket 11
# DEBUG:MyHashTable:get 4
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found correct bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=8, collisions=0)
# DEBUG:MyHashTable:get 4: 4 from bucket 29
# DEBUG:MyHashTable:get 7
# DEBUG:MyHashTable:Looking for key 7 in bucket 52
# DEBUG:MyHashTable:Found correct bucket 52 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=8, collisions=0)
# DEBUG:MyHashTable:get 7: 7 from bucket 52
# DEBUG:MyHashTable:get 2
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found correct bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=8, collisions=0)
# DEBUG:MyHashTable:get 2: 2 from bucket 55
# DEBUG:MyHashTable:get 6
# DEBUG:MyHashTable:Looking for key 6 in bucket 65
# DEBUG:MyHashTable:Found correct bucket 65 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=8, collisions=0)
# DEBUG:MyHashTable:get 6: 6 from bucket 65
# DEBUG:MyHashTable:get 0
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found correct bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=8, collisions=0)
# DEBUG:MyHashTable:get 0: 0 from bucket 73
# DEBUG:MyHashTable:get 1
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found correct bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=8, collisions=0)
# DEBUG:MyHashTable:get 1: 1 from bucket 92
# DEBUG:MyHashTable:set 0: 0 (start)
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found empty bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=0, collisions=0)
# DEBUG:MyHashTable:set 0: 0 -> bucket 73 (1 / 100 (1.0%))
# DEBUG:MyHashTable:set 1: 1 (start)
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found empty bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=1, collisions=0)
# DEBUG:MyHashTable:set 1: 1 -> bucket 92 (2 / 100 (2.0%))
# DEBUG:MyHashTable:set 2: 2 (start)
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found empty bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=2, collisions=0)
# DEBUG:MyHashTable:set 2: 2 -> bucket 55 (3 / 100 (3.0%))
# DEBUG:MyHashTable:set 3: 3 (start)
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found empty bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=3, collisions=0)
# DEBUG:MyHashTable:set 3: 3 -> bucket 5 (4 / 100 (4.0%))
# DEBUG:MyHashTable:set 4: 4 (start)
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found empty bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=4, collisions=0)
# DEBUG:MyHashTable:set 4: 4 -> bucket 29 (5 / 100 (5.0%))
# DEBUG:MyHashTable:set 5: 5 (start)
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found empty bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=5, collisions=0)
# DEBUG:MyHashTable:set 5: 5 -> bucket 11 (6 / 100 (6.0%))
# DEBUG:MyHashTable:set 6: 6 (start)
# DEBUG:MyHashTable:Looking for key 6 in bucket 65
# DEBUG:MyHashTable:Found empty bucket 65 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:set 6: 6 -> bucket 65 (7 / 100 (7.0%))
# DEBUG:MyHashTable:set 7: 7 (start)
# DEBUG:MyHashTable:Looking for key 7 in bucket 52
# DEBUG:MyHashTable:Found empty bucket 52 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=7, collisions=0)
# DEBUG:MyHashTable:set 7: 7 -> bucket 52 (8 / 100 (8.0%))
# DEBUG:MyHashTable:set 8: 8 (start)
# DEBUG:MyHashTable:Looking for key 8 in bucket 47
# DEBUG:MyHashTable:Found empty bucket 47 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=8, collisions=0)
# DEBUG:MyHashTable:set 8: 8 -> bucket 47 (9 / 100 (9.0%))
# DEBUG:MyHashTable:get 3
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found correct bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=9, collisions=0)
# DEBUG:MyHashTable:get 3: 3 from bucket 5
# DEBUG:MyHashTable:get 5
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found correct bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=9, collisions=0)
# DEBUG:MyHashTable:get 5: 5 from bucket 11
# DEBUG:MyHashTable:get 4
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found correct bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=9, collisions=0)
# DEBUG:MyHashTable:get 4: 4 from bucket 29
# DEBUG:MyHashTable:get 8
# DEBUG:MyHashTable:Looking for key 8 in bucket 47
# DEBUG:MyHashTable:Found correct bucket 47 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=9, collisions=0)
# DEBUG:MyHashTable:get 8: 8 from bucket 47
# DEBUG:MyHashTable:get 7
# DEBUG:MyHashTable:Looking for key 7 in bucket 52
# DEBUG:MyHashTable:Found correct bucket 52 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=9, collisions=0)
# DEBUG:MyHashTable:get 7: 7 from bucket 52
# DEBUG:MyHashTable:get 2
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found correct bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=9, collisions=0)
# DEBUG:MyHashTable:get 2: 2 from bucket 55
# DEBUG:MyHashTable:get 6
# DEBUG:MyHashTable:Looking for key 6 in bucket 65
# DEBUG:MyHashTable:Found correct bucket 65 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=9, collisions=0)
# DEBUG:MyHashTable:get 6: 6 from bucket 65
# DEBUG:MyHashTable:get 0
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found correct bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=9, collisions=0)
# DEBUG:MyHashTable:get 0: 0 from bucket 73
# DEBUG:MyHashTable:get 1
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found correct bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=9, collisions=0)
# DEBUG:MyHashTable:get 1: 1 from bucket 92
# DEBUG:MyHashTable:set 0: 0 (start)
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found empty bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=0, collisions=0)
# DEBUG:MyHashTable:set 0: 0 -> bucket 73 (1 / 100 (1.0%))
# DEBUG:MyHashTable:set 1: 1 (start)
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found empty bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=1, collisions=0)
# DEBUG:MyHashTable:set 1: 1 -> bucket 92 (2 / 100 (2.0%))
# DEBUG:MyHashTable:set 2: 2 (start)
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found empty bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=2, collisions=0)
# DEBUG:MyHashTable:set 2: 2 -> bucket 55 (3 / 100 (3.0%))
# DEBUG:MyHashTable:set 3: 3 (start)
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found empty bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=3, collisions=0)
# DEBUG:MyHashTable:set 3: 3 -> bucket 5 (4 / 100 (4.0%))
# DEBUG:MyHashTable:set 4: 4 (start)
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found empty bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=4, collisions=0)
# DEBUG:MyHashTable:set 4: 4 -> bucket 29 (5 / 100 (5.0%))
# DEBUG:MyHashTable:set 5: 5 (start)
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found empty bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=5, collisions=0)
# DEBUG:MyHashTable:set 5: 5 -> bucket 11 (6 / 100 (6.0%))
# DEBUG:MyHashTable:set 6: 6 (start)
# DEBUG:MyHashTable:Looking for key 6 in bucket 65
# DEBUG:MyHashTable:Found empty bucket 65 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:set 6: 6 -> bucket 65 (7 / 100 (7.0%))
# DEBUG:MyHashTable:set 7: 7 (start)
# DEBUG:MyHashTable:Looking for key 7 in bucket 52
# DEBUG:MyHashTable:Found empty bucket 52 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=7, collisions=0)
# DEBUG:MyHashTable:set 7: 7 -> bucket 52 (8 / 100 (8.0%))
# DEBUG:MyHashTable:set 8: 8 (start)
# DEBUG:MyHashTable:Looking for key 8 in bucket 47
# DEBUG:MyHashTable:Found empty bucket 47 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=8, collisions=0)
# DEBUG:MyHashTable:set 8: 8 -> bucket 47 (9 / 100 (9.0%))
# DEBUG:MyHashTable:set 9: 9 (start)
# DEBUG:MyHashTable:Looking for key 9 in bucket 48
# DEBUG:MyHashTable:Found empty bucket 48 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=9, collisions=0)
# DEBUG:MyHashTable:set 9: 9 -> bucket 48 (10 / 100 (10.0%))
# DEBUG:MyHashTable:get 3
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found correct bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=10, collisions=0)
# DEBUG:MyHashTable:get 3: 3 from bucket 5
# DEBUG:MyHashTable:get 5
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found correct bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=10, collisions=0)
# DEBUG:MyHashTable:get 5: 5 from bucket 11
# DEBUG:MyHashTable:get 4
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found correct bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=10, collisions=0)
# DEBUG:MyHashTable:get 4: 4 from bucket 29
# DEBUG:MyHashTable:get 8
# DEBUG:MyHashTable:Looking for key 8 in bucket 47
# DEBUG:MyHashTable:Found correct bucket 47 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=10, collisions=0)
# DEBUG:MyHashTable:get 8: 8 from bucket 47
# DEBUG:MyHashTable:get 9
# DEBUG:MyHashTable:Looking for key 9 in bucket 48
# DEBUG:MyHashTable:Found correct bucket 48 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=10, collisions=0)
# DEBUG:MyHashTable:get 9: 9 from bucket 48
# DEBUG:MyHashTable:get 7
# DEBUG:MyHashTable:Looking for key 7 in bucket 52
# DEBUG:MyHashTable:Found correct bucket 52 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=10, collisions=0)
# DEBUG:MyHashTable:get 7: 7 from bucket 52
# DEBUG:MyHashTable:get 2
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found correct bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=10, collisions=0)
# DEBUG:MyHashTable:get 2: 2 from bucket 55
# DEBUG:MyHashTable:get 6
# DEBUG:MyHashTable:Looking for key 6 in bucket 65
# DEBUG:MyHashTable:Found correct bucket 65 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=10, collisions=0)
# DEBUG:MyHashTable:get 6: 6 from bucket 65
# DEBUG:MyHashTable:get 0
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found correct bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=10, collisions=0)
# DEBUG:MyHashTable:get 0: 0 from bucket 73
# DEBUG:MyHashTable:get 1
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found correct bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=10, collisions=0)
# DEBUG:MyHashTable:get 1: 1 from bucket 92
# DEBUG:MyHashTable:set 0: 0 (start)
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found empty bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=0, collisions=0)
# DEBUG:MyHashTable:set 0: 0 -> bucket 73 (1 / 100 (1.0%))
# DEBUG:MyHashTable:set 1: 1 (start)
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found empty bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=1, collisions=0)
# DEBUG:MyHashTable:set 1: 1 -> bucket 92 (2 / 100 (2.0%))
# DEBUG:MyHashTable:set 2: 2 (start)
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found empty bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=2, collisions=0)
# DEBUG:MyHashTable:set 2: 2 -> bucket 55 (3 / 100 (3.0%))
# DEBUG:MyHashTable:set 3: 3 (start)
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found empty bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=3, collisions=0)
# DEBUG:MyHashTable:set 3: 3 -> bucket 5 (4 / 100 (4.0%))
# DEBUG:MyHashTable:set 4: 4 (start)
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found empty bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=4, collisions=0)
# DEBUG:MyHashTable:set 4: 4 -> bucket 29 (5 / 100 (5.0%))
# DEBUG:MyHashTable:set 5: 5 (start)
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found empty bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=5, collisions=0)
# DEBUG:MyHashTable:set 5: 5 -> bucket 11 (6 / 100 (6.0%))
# DEBUG:MyHashTable:set 6: 6 (start)
# DEBUG:MyHashTable:Looking for key 6 in bucket 65
# DEBUG:MyHashTable:Found empty bucket 65 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:set 6: 6 -> bucket 65 (7 / 100 (7.0%))
# DEBUG:MyHashTable:set 7: 7 (start)
# DEBUG:MyHashTable:Looking for key 7 in bucket 52
# DEBUG:MyHashTable:Found empty bucket 52 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=7, collisions=0)
# DEBUG:MyHashTable:set 7: 7 -> bucket 52 (8 / 100 (8.0%))
# DEBUG:MyHashTable:set 8: 8 (start)
# DEBUG:MyHashTable:Looking for key 8 in bucket 47
# DEBUG:MyHashTable:Found empty bucket 47 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=8, collisions=0)
# DEBUG:MyHashTable:set 8: 8 -> bucket 47 (9 / 100 (9.0%))
# DEBUG:MyHashTable:set 9: 9 (start)
# DEBUG:MyHashTable:Looking for key 9 in bucket 48
# DEBUG:MyHashTable:Found empty bucket 48 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=9, collisions=0)
# DEBUG:MyHashTable:set 9: 9 -> bucket 48 (10 / 100 (10.0%))
# DEBUG:MyHashTable:set 10: 10 (start)
# DEBUG:MyHashTable:Looking for key 10 in bucket 80
# DEBUG:MyHashTable:Found empty bucket 80 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=10, collisions=0)
# DEBUG:MyHashTable:set 10: 10 -> bucket 80 (11 / 100 (11.0%))
# DEBUG:MyHashTable:get 3
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found correct bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=11, collisions=0)
# DEBUG:MyHashTable:get 3: 3 from bucket 5
# DEBUG:MyHashTable:get 5
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found correct bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=11, collisions=0)
# DEBUG:MyHashTable:get 5: 5 from bucket 11
# DEBUG:MyHashTable:get 4
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found correct bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=11, collisions=0)
# DEBUG:MyHashTable:get 4: 4 from bucket 29
# DEBUG:MyHashTable:get 8
# DEBUG:MyHashTable:Looking for key 8 in bucket 47
# DEBUG:MyHashTable:Found correct bucket 47 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=11, collisions=0)
# DEBUG:MyHashTable:get 8: 8 from bucket 47
# DEBUG:MyHashTable:get 9
# DEBUG:MyHashTable:Looking for key 9 in bucket 48
# DEBUG:MyHashTable:Found correct bucket 48 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=11, collisions=0)
# DEBUG:MyHashTable:get 9: 9 from bucket 48
# DEBUG:MyHashTable:get 7
# DEBUG:MyHashTable:Looking for key 7 in bucket 52
# DEBUG:MyHashTable:Found correct bucket 52 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=11, collisions=0)
# DEBUG:MyHashTable:get 7: 7 from bucket 52
# DEBUG:MyHashTable:get 2
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found correct bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=11, collisions=0)
# DEBUG:MyHashTable:get 2: 2 from bucket 55
# DEBUG:MyHashTable:get 6
# DEBUG:MyHashTable:Looking for key 6 in bucket 65
# DEBUG:MyHashTable:Found correct bucket 65 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=11, collisions=0)
# DEBUG:MyHashTable:get 6: 6 from bucket 65
# DEBUG:MyHashTable:get 0
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found correct bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=11, collisions=0)
# DEBUG:MyHashTable:get 0: 0 from bucket 73
# DEBUG:MyHashTable:get 10
# DEBUG:MyHashTable:Looking for key 10 in bucket 80
# DEBUG:MyHashTable:Found correct bucket 80 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=11, collisions=0)
# DEBUG:MyHashTable:get 10: 10 from bucket 80
# DEBUG:MyHashTable:get 1
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found correct bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=11, collisions=0)
# DEBUG:MyHashTable:get 1: 1 from bucket 92
# DEBUG:MyHashTable:set 0: 0 (start)
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found empty bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=0, collisions=0)
# DEBUG:MyHashTable:set 0: 0 -> bucket 73 (1 / 100 (1.0%))
# DEBUG:MyHashTable:set 1: 1 (start)
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found empty bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=1, collisions=0)
# DEBUG:MyHashTable:set 1: 1 -> bucket 92 (2 / 100 (2.0%))
# DEBUG:MyHashTable:set 2: 2 (start)
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found empty bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=2, collisions=0)
# DEBUG:MyHashTable:set 2: 2 -> bucket 55 (3 / 100 (3.0%))
# DEBUG:MyHashTable:set 3: 3 (start)
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found empty bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=3, collisions=0)
# DEBUG:MyHashTable:set 3: 3 -> bucket 5 (4 / 100 (4.0%))
# DEBUG:MyHashTable:set 4: 4 (start)
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found empty bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=4, collisions=0)
# DEBUG:MyHashTable:set 4: 4 -> bucket 29 (5 / 100 (5.0%))
# DEBUG:MyHashTable:set 5: 5 (start)
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found empty bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=5, collisions=0)
# DEBUG:MyHashTable:set 5: 5 -> bucket 11 (6 / 100 (6.0%))
# DEBUG:MyHashTable:set 6: 6 (start)
# DEBUG:MyHashTable:Looking for key 6 in bucket 65
# DEBUG:MyHashTable:Found empty bucket 65 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:set 6: 6 -> bucket 65 (7 / 100 (7.0%))
# DEBUG:MyHashTable:set 7: 7 (start)
# DEBUG:MyHashTable:Looking for key 7 in bucket 52
# DEBUG:MyHashTable:Found empty bucket 52 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=7, collisions=0)
# DEBUG:MyHashTable:set 7: 7 -> bucket 52 (8 / 100 (8.0%))
# DEBUG:MyHashTable:set 8: 8 (start)
# DEBUG:MyHashTable:Looking for key 8 in bucket 47
# DEBUG:MyHashTable:Found empty bucket 47 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=8, collisions=0)
# DEBUG:MyHashTable:set 8: 8 -> bucket 47 (9 / 100 (9.0%))
# DEBUG:MyHashTable:set 9: 9 (start)
# DEBUG:MyHashTable:Looking for key 9 in bucket 48
# DEBUG:MyHashTable:Found empty bucket 48 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=9, collisions=0)
# DEBUG:MyHashTable:set 9: 9 -> bucket 48 (10 / 100 (10.0%))
# DEBUG:MyHashTable:set 10: 10 (start)
# DEBUG:MyHashTable:Looking for key 10 in bucket 80
# DEBUG:MyHashTable:Found empty bucket 80 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=10, collisions=0)
# DEBUG:MyHashTable:set 10: 10 -> bucket 80 (11 / 100 (11.0%))
# DEBUG:MyHashTable:set 11: 11 (start)
# DEBUG:MyHashTable:Looking for key 11 in bucket 92
# DEBUG:MyHashTable:Found collision at bucket 92
# DEBUG:MyHashTable:Looking for key 11 in bucket 93
# DEBUG:MyHashTable:Found empty bucket 93 after 1 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=11, collisions=1)
# DEBUG:MyHashTable:set 11: 11 -> bucket 93 (12 / 100 (12.0%))
# DEBUG:MyHashTable:get 3
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found correct bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=12, collisions=0)
# DEBUG:MyHashTable:get 3: 3 from bucket 5
# DEBUG:MyHashTable:get 5
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found correct bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=12, collisions=0)
# DEBUG:MyHashTable:get 5: 5 from bucket 11
# DEBUG:MyHashTable:get 4
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found correct bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=12, collisions=0)
# DEBUG:MyHashTable:get 4: 4 from bucket 29
# DEBUG:MyHashTable:get 8
# DEBUG:MyHashTable:Looking for key 8 in bucket 47
# DEBUG:MyHashTable:Found correct bucket 47 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=12, collisions=0)
# DEBUG:MyHashTable:get 8: 8 from bucket 47
# DEBUG:MyHashTable:get 9
# DEBUG:MyHashTable:Looking for key 9 in bucket 48
# DEBUG:MyHashTable:Found correct bucket 48 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=12, collisions=0)
# DEBUG:MyHashTable:get 9: 9 from bucket 48
# DEBUG:MyHashTable:get 7
# DEBUG:MyHashTable:Looking for key 7 in bucket 52
# DEBUG:MyHashTable:Found correct bucket 52 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=12, collisions=0)
# DEBUG:MyHashTable:get 7: 7 from bucket 52
# DEBUG:MyHashTable:get 2
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found correct bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=12, collisions=0)
# DEBUG:MyHashTable:get 2: 2 from bucket 55
# DEBUG:MyHashTable:get 6
# DEBUG:MyHashTable:Looking for key 6 in bucket 65
# DEBUG:MyHashTable:Found correct bucket 65 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=12, collisions=0)
# DEBUG:MyHashTable:get 6: 6 from bucket 65
# DEBUG:MyHashTable:get 0
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found correct bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=12, collisions=0)
# DEBUG:MyHashTable:get 0: 0 from bucket 73
# DEBUG:MyHashTable:get 10
# DEBUG:MyHashTable:Looking for key 10 in bucket 80
# DEBUG:MyHashTable:Found correct bucket 80 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=12, collisions=0)
# DEBUG:MyHashTable:get 10: 10 from bucket 80
# DEBUG:MyHashTable:get 1
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found correct bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=12, collisions=0)
# DEBUG:MyHashTable:get 1: 1 from bucket 92
# DEBUG:MyHashTable:get 11
# DEBUG:MyHashTable:Looking for key 11 in bucket 92
# DEBUG:MyHashTable:Found collision at bucket 92
# DEBUG:MyHashTable:Looking for key 11 in bucket 93
# DEBUG:MyHashTable:Found correct bucket 93 after 1 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=12, collisions=1)
# DEBUG:MyHashTable:get 11: 11 from bucket 93
# DEBUG:MyHashTable:set 0: 0 (start)
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found empty bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=0, collisions=0)
# DEBUG:MyHashTable:set 0: 0 -> bucket 73 (1 / 100 (1.0%))
# DEBUG:MyHashTable:set 1: 1 (start)
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found empty bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=1, collisions=0)
# DEBUG:MyHashTable:set 1: 1 -> bucket 92 (2 / 100 (2.0%))
# DEBUG:MyHashTable:set 2: 2 (start)
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found empty bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=2, collisions=0)
# DEBUG:MyHashTable:set 2: 2 -> bucket 55 (3 / 100 (3.0%))
# DEBUG:MyHashTable:set 3: 3 (start)
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found empty bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=3, collisions=0)
# DEBUG:MyHashTable:set 3: 3 -> bucket 5 (4 / 100 (4.0%))
# DEBUG:MyHashTable:set 4: 4 (start)
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found empty bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=4, collisions=0)
# DEBUG:MyHashTable:set 4: 4 -> bucket 29 (5 / 100 (5.0%))
# DEBUG:MyHashTable:set 5: 5 (start)
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found empty bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=5, collisions=0)
# DEBUG:MyHashTable:set 5: 5 -> bucket 11 (6 / 100 (6.0%))
# DEBUG:MyHashTable:set 6: 6 (start)
# DEBUG:MyHashTable:Looking for key 6 in bucket 65
# DEBUG:MyHashTable:Found empty bucket 65 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:set 6: 6 -> bucket 65 (7 / 100 (7.0%))
# DEBUG:MyHashTable:set 7: 7 (start)
# DEBUG:MyHashTable:Looking for key 7 in bucket 52
# DEBUG:MyHashTable:Found empty bucket 52 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=7, collisions=0)
# DEBUG:MyHashTable:set 7: 7 -> bucket 52 (8 / 100 (8.0%))
# DEBUG:MyHashTable:set 8: 8 (start)
# DEBUG:MyHashTable:Looking for key 8 in bucket 47
# DEBUG:MyHashTable:Found empty bucket 47 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=8, collisions=0)
# DEBUG:MyHashTable:set 8: 8 -> bucket 47 (9 / 100 (9.0%))
# DEBUG:MyHashTable:set 9: 9 (start)
# DEBUG:MyHashTable:Looking for key 9 in bucket 48
# DEBUG:MyHashTable:Found empty bucket 48 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=9, collisions=0)
# DEBUG:MyHashTable:set 9: 9 -> bucket 48 (10 / 100 (10.0%))
# DEBUG:MyHashTable:set 10: 10 (start)
# DEBUG:MyHashTable:Looking for key 10 in bucket 80
# DEBUG:MyHashTable:Found empty bucket 80 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=10, collisions=0)
# DEBUG:MyHashTable:set 10: 10 -> bucket 80 (11 / 100 (11.0%))
# DEBUG:MyHashTable:set 11: 11 (start)
# DEBUG:MyHashTable:Looking for key 11 in bucket 92
# DEBUG:MyHashTable:Found collision at bucket 92
# DEBUG:MyHashTable:Looking for key 11 in bucket 93
# DEBUG:MyHashTable:Found empty bucket 93 after 1 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=11, collisions=1)
# DEBUG:MyHashTable:set 11: 11 -> bucket 93 (12 / 100 (12.0%))
# DEBUG:MyHashTable:set 12: 12 (start)
# DEBUG:MyHashTable:Looking for key 12 in bucket 32
# DEBUG:MyHashTable:Found empty bucket 32 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=12, collisions=0)
# DEBUG:MyHashTable:set 12: 12 -> bucket 32 (13 / 100 (13.0%))
# DEBUG:MyHashTable:get 3
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found correct bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=13, collisions=0)
# DEBUG:MyHashTable:get 3: 3 from bucket 5
# DEBUG:MyHashTable:get 5
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found correct bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=13, collisions=0)
# DEBUG:MyHashTable:get 5: 5 from bucket 11
# DEBUG:MyHashTable:get 4
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found correct bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=13, collisions=0)
# DEBUG:MyHashTable:get 4: 4 from bucket 29
# DEBUG:MyHashTable:get 12
# DEBUG:MyHashTable:Looking for key 12 in bucket 32
# DEBUG:MyHashTable:Found correct bucket 32 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=13, collisions=0)
# DEBUG:MyHashTable:get 12: 12 from bucket 32
# DEBUG:MyHashTable:get 8
# DEBUG:MyHashTable:Looking for key 8 in bucket 47
# DEBUG:MyHashTable:Found correct bucket 47 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=13, collisions=0)
# DEBUG:MyHashTable:get 8: 8 from bucket 47
# DEBUG:MyHashTable:get 9
# DEBUG:MyHashTable:Looking for key 9 in bucket 48
# DEBUG:MyHashTable:Found correct bucket 48 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=13, collisions=0)
# DEBUG:MyHashTable:get 9: 9 from bucket 48
# DEBUG:MyHashTable:get 7
# DEBUG:MyHashTable:Looking for key 7 in bucket 52
# DEBUG:MyHashTable:Found correct bucket 52 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=13, collisions=0)
# DEBUG:MyHashTable:get 7: 7 from bucket 52
# DEBUG:MyHashTable:get 2
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# ...
# DEBUG:MyHashTable:Found correct bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=23, collisions=0)
# DEBUG:MyHashTable:get 2: 2 from bucket 55
# DEBUG:MyHashTable:get 18
# DEBUG:MyHashTable:Looking for key 18 in bucket 59
# DEBUG:MyHashTable:Found correct bucket 59 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=23, collisions=0)
# DEBUG:MyHashTable:get 18: 18 from bucket 59
# DEBUG:MyHashTable:get 22
# DEBUG:MyHashTable:Looking for key 22 in bucket 61
# DEBUG:MyHashTable:Found correct bucket 61 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=23, collisions=0)
# DEBUG:MyHashTable:get 22: 22 from bucket 61
# DEBUG:MyHashTable:get 6
# DEBUG:MyHashTable:Looking for key 6 in bucket 65
# DEBUG:MyHashTable:Found correct bucket 65 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=23, collisions=0)
# DEBUG:MyHashTable:get 6: 6 from bucket 65
# DEBUG:MyHashTable:get 0
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found correct bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=23, collisions=0)
# DEBUG:MyHashTable:get 0: 0 from bucket 73
# DEBUG:MyHashTable:get 13
# DEBUG:MyHashTable:Looking for key 13 in bucket 76
# DEBUG:MyHashTable:Found correct bucket 76 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=23, collisions=0)
# DEBUG:MyHashTable:get 13: 13 from bucket 76
# DEBUG:MyHashTable:get 19
# DEBUG:MyHashTable:Looking for key 19 in bucket 77
# DEBUG:MyHashTable:Found correct bucket 77 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=23, collisions=0)
# DEBUG:MyHashTable:get 19: 19 from bucket 77
# DEBUG:MyHashTable:get 10
# DEBUG:MyHashTable:Looking for key 10 in bucket 80
# DEBUG:MyHashTable:Found correct bucket 80 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=23, collisions=0)
# DEBUG:MyHashTable:get 10: 10 from bucket 80
# DEBUG:MyHashTable:get 20
# DEBUG:MyHashTable:Looking for key 20 in bucket 86
# DEBUG:MyHashTable:Found correct bucket 86 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=23, collisions=0)
# DEBUG:MyHashTable:get 20: 20 from bucket 86
# DEBUG:MyHashTable:get 1
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found correct bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=23, collisions=0)
# DEBUG:MyHashTable:get 1: 1 from bucket 92
# DEBUG:MyHashTable:get 11
# DEBUG:MyHashTable:Looking for key 11 in bucket 92
# DEBUG:MyHashTable:Found collision at bucket 92
# DEBUG:MyHashTable:Looking for key 11 in bucket 93
# DEBUG:MyHashTable:Found correct bucket 93 after 1 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=23, collisions=1)
# DEBUG:MyHashTable:get 11: 11 from bucket 93
# DEBUG:MyHashTable:get 17
# DEBUG:MyHashTable:Looking for key 17 in bucket 95
# DEBUG:MyHashTable:Found correct bucket 95 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=23, collisions=0)
# DEBUG:MyHashTable:get 17: 17 from bucket 95
# DEBUG:MyHashTable:get 16
# DEBUG:MyHashTable:Looking for key 16 in bucket 99
# DEBUG:MyHashTable:Found correct bucket 99 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=23, collisions=0)
# DEBUG:MyHashTable:get 16: 16 from bucket 99
# DEBUG:MyHashTable:set 0: 0 (start)
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found empty bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=0, collisions=0)
# DEBUG:MyHashTable:set 0: 0 -> bucket 73 (1 / 100 (1.0%))
# DEBUG:MyHashTable:set 1: 1 (start)
# DEBUG:MyHashTable:Looking for key 1 in bucket 92
# DEBUG:MyHashTable:Found empty bucket 92 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=1, collisions=0)
# DEBUG:MyHashTable:set 1: 1 -> bucket 92 (2 / 100 (2.0%))
# DEBUG:MyHashTable:set 2: 2 (start)
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found empty bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=2, collisions=0)
# DEBUG:MyHashTable:set 2: 2 -> bucket 55 (3 / 100 (3.0%))
# DEBUG:MyHashTable:set 3: 3 (start)
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found empty bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=3, collisions=0)
# DEBUG:MyHashTable:set 3: 3 -> bucket 5 (4 / 100 (4.0%))
# DEBUG:MyHashTable:set 4: 4 (start)
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found empty bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=4, collisions=0)
# DEBUG:MyHashTable:set 4: 4 -> bucket 29 (5 / 100 (5.0%))
# DEBUG:MyHashTable:set 5: 5 (start)
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found empty bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=5, collisions=0)
# DEBUG:MyHashTable:set 5: 5 -> bucket 11 (6 / 100 (6.0%))
# DEBUG:MyHashTable:set 6: 6 (start)
# DEBUG:MyHashTable:Looking for key 6 in bucket 65
# DEBUG:MyHashTable:Found empty bucket 65 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=6, collisions=0)
# DEBUG:MyHashTable:set 6: 6 -> bucket 65 (7 / 100 (7.0%))
# DEBUG:MyHashTable:set 7: 7 (start)
# DEBUG:MyHashTable:Looking for key 7 in bucket 52
# DEBUG:MyHashTable:Found empty bucket 52 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=7, collisions=0)
# DEBUG:MyHashTable:set 7: 7 -> bucket 52 (8 / 100 (8.0%))
# DEBUG:MyHashTable:set 8: 8 (start)
# DEBUG:MyHashTable:Looking for key 8 in bucket 47
# DEBUG:MyHashTable:Found empty bucket 47 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=8, collisions=0)
# DEBUG:MyHashTable:set 8: 8 -> bucket 47 (9 / 100 (9.0%))
# DEBUG:MyHashTable:set 9: 9 (start)
# DEBUG:MyHashTable:Looking for key 9 in bucket 48
# DEBUG:MyHashTable:Found empty bucket 48 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=9, collisions=0)
# DEBUG:MyHashTable:set 9: 9 -> bucket 48 (10 / 100 (10.0%))
# DEBUG:MyHashTable:set 10: 10 (start)
# DEBUG:MyHashTable:Looking for key 10 in bucket 80
# DEBUG:MyHashTable:Found empty bucket 80 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=10, collisions=0)
# DEBUG:MyHashTable:set 10: 10 -> bucket 80 (11 / 100 (11.0%))
# DEBUG:MyHashTable:set 11: 11 (start)
# DEBUG:MyHashTable:Looking for key 11 in bucket 92
# DEBUG:MyHashTable:Found collision at bucket 92
# DEBUG:MyHashTable:Looking for key 11 in bucket 93
# DEBUG:MyHashTable:Found empty bucket 93 after 1 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=11, collisions=1)
# DEBUG:MyHashTable:set 11: 11 -> bucket 93 (12 / 100 (12.0%))
# DEBUG:MyHashTable:set 12: 12 (start)
# DEBUG:MyHashTable:Looking for key 12 in bucket 32
# DEBUG:MyHashTable:Found empty bucket 32 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=12, collisions=0)
# DEBUG:MyHashTable:set 12: 12 -> bucket 32 (13 / 100 (13.0%))
# DEBUG:MyHashTable:set 13: 13 (start)
# DEBUG:MyHashTable:Looking for key 13 in bucket 76
# DEBUG:MyHashTable:Found empty bucket 76 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=13, collisions=0)
# DEBUG:MyHashTable:set 13: 13 -> bucket 76 (14 / 100 (14.0%))
# DEBUG:MyHashTable:set 14: 14 (start)
# DEBUG:MyHashTable:Looking for key 14 in bucket 6
# DEBUG:MyHashTable:Found empty bucket 6 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=14, collisions=0)
# DEBUG:MyHashTable:set 14: 14 -> bucket 6 (15 / 100 (15.0%))
# DEBUG:MyHashTable:set 15: 15 (start)
# DEBUG:MyHashTable:Looking for key 15 in bucket 46
# DEBUG:MyHashTable:Found empty bucket 46 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=15, collisions=0)
# DEBUG:MyHashTable:set 15: 15 -> bucket 46 (16 / 100 (16.0%))
# DEBUG:MyHashTable:set 16: 16 (start)
# DEBUG:MyHashTable:Looking for key 16 in bucket 99
# DEBUG:MyHashTable:Found empty bucket 99 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=16, collisions=0)
# DEBUG:MyHashTable:set 16: 16 -> bucket 99 (17 / 100 (17.0%))
# DEBUG:MyHashTable:set 17: 17 (start)
# DEBUG:MyHashTable:Looking for key 17 in bucket 95
# DEBUG:MyHashTable:Found empty bucket 95 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=17, collisions=0)
# DEBUG:MyHashTable:set 17: 17 -> bucket 95 (18 / 100 (18.0%))
# DEBUG:MyHashTable:set 18: 18 (start)
# DEBUG:MyHashTable:Looking for key 18 in bucket 59
# DEBUG:MyHashTable:Found empty bucket 59 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=18, collisions=0)
# DEBUG:MyHashTable:set 18: 18 -> bucket 59 (19 / 100 (19.0%))
# DEBUG:MyHashTable:set 19: 19 (start)
# DEBUG:MyHashTable:Looking for key 19 in bucket 77
# DEBUG:MyHashTable:Found empty bucket 77 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=19, collisions=0)
# DEBUG:MyHashTable:set 19: 19 -> bucket 77 (20 / 100 (20.0%))
# DEBUG:MyHashTable:set 20: 20 (start)
# DEBUG:MyHashTable:Looking for key 20 in bucket 86
# DEBUG:MyHashTable:Found empty bucket 86 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=20, collisions=0)
# DEBUG:MyHashTable:set 20: 20 -> bucket 86 (21 / 100 (21.0%))
# DEBUG:MyHashTable:set 21: 21 (start)
# DEBUG:MyHashTable:Looking for key 21 in bucket 29
# DEBUG:MyHashTable:Found collision at bucket 29
# DEBUG:MyHashTable:Looking for key 21 in bucket 30
# DEBUG:MyHashTable:Found empty bucket 30 after 1 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=21, collisions=1)
# DEBUG:MyHashTable:set 21: 21 -> bucket 30 (22 / 100 (22.0%))
# DEBUG:MyHashTable:set 22: 22 (start)
# DEBUG:MyHashTable:Looking for key 22 in bucket 61
# DEBUG:MyHashTable:Found empty bucket 61 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=22, collisions=0)
# DEBUG:MyHashTable:set 22: 22 -> bucket 61 (23 / 100 (23.0%))
# DEBUG:MyHashTable:set 23: 23 (start)
# DEBUG:MyHashTable:Looking for key 23 in bucket 46
# DEBUG:MyHashTable:Found collision at bucket 46
# DEBUG:MyHashTable:Looking for key 23 in bucket 47
# DEBUG:MyHashTable:Found collision at bucket 47
# DEBUG:MyHashTable:Looking for key 23 in bucket 48
# DEBUG:MyHashTable:Found collision at bucket 48
# DEBUG:MyHashTable:Looking for key 23 in bucket 49
# DEBUG:MyHashTable:Found empty bucket 49 after 3 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=23, collisions=3)
# DEBUG:MyHashTable:set 23: 23 -> bucket 49 (24 / 100 (24.0%))
# DEBUG:MyHashTable:get 3
# DEBUG:MyHashTable:Looking for key 3 in bucket 5
# DEBUG:MyHashTable:Found correct bucket 5 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=0)
# DEBUG:MyHashTable:get 3: 3 from bucket 5
# DEBUG:MyHashTable:get 14
# DEBUG:MyHashTable:Looking for key 14 in bucket 6
# DEBUG:MyHashTable:Found correct bucket 6 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=0)
# DEBUG:MyHashTable:get 14: 14 from bucket 6
# DEBUG:MyHashTable:get 5
# DEBUG:MyHashTable:Looking for key 5 in bucket 11
# DEBUG:MyHashTable:Found correct bucket 11 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=0)
# DEBUG:MyHashTable:get 5: 5 from bucket 11
# DEBUG:MyHashTable:get 4
# DEBUG:MyHashTable:Looking for key 4 in bucket 29
# DEBUG:MyHashTable:Found correct bucket 29 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=0)
# DEBUG:MyHashTable:get 4: 4 from bucket 29
# DEBUG:MyHashTable:get 21
# DEBUG:MyHashTable:Looking for key 21 in bucket 29
# DEBUG:MyHashTable:Found collision at bucket 29
# DEBUG:MyHashTable:Looking for key 21 in bucket 30
# DEBUG:MyHashTable:Found correct bucket 30 after 1 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=1)
# DEBUG:MyHashTable:get 21: 21 from bucket 30
# DEBUG:MyHashTable:get 12
# DEBUG:MyHashTable:Looking for key 12 in bucket 32
# DEBUG:MyHashTable:Found correct bucket 32 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=0)
# DEBUG:MyHashTable:get 12: 12 from bucket 32
# DEBUG:MyHashTable:get 15
# DEBUG:MyHashTable:Looking for key 15 in bucket 46
# DEBUG:MyHashTable:Found correct bucket 46 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=0)
# DEBUG:MyHashTable:get 15: 15 from bucket 46
# DEBUG:MyHashTable:get 8
# DEBUG:MyHashTable:Looking for key 8 in bucket 47
# DEBUG:MyHashTable:Found correct bucket 47 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=0)
# DEBUG:MyHashTable:get 8: 8 from bucket 47
# DEBUG:MyHashTable:get 9
# DEBUG:MyHashTable:Looking for key 9 in bucket 48
# DEBUG:MyHashTable:Found correct bucket 48 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=0)
# DEBUG:MyHashTable:get 9: 9 from bucket 48
# DEBUG:MyHashTable:get 23
# DEBUG:MyHashTable:Looking for key 23 in bucket 46
# DEBUG:MyHashTable:Found collision at bucket 46
# DEBUG:MyHashTable:Looking for key 23 in bucket 47
# DEBUG:MyHashTable:Found collision at bucket 47
# DEBUG:MyHashTable:Looking for key 23 in bucket 48
# DEBUG:MyHashTable:Found collision at bucket 48
# DEBUG:MyHashTable:Looking for key 23 in bucket 49
# DEBUG:MyHashTable:Found correct bucket 49 after 3 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=3)
# DEBUG:MyHashTable:get 23: 23 from bucket 49
# DEBUG:MyHashTable:get 7
# DEBUG:MyHashTable:Looking for key 7 in bucket 52
# DEBUG:MyHashTable:Found correct bucket 52 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=0)
# DEBUG:MyHashTable:get 7: 7 from bucket 52
# DEBUG:MyHashTable:get 2
# DEBUG:MyHashTable:Looking for key 2 in bucket 55
# DEBUG:MyHashTable:Found correct bucket 55 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=0)
# DEBUG:MyHashTable:get 2: 2 from bucket 55
# DEBUG:MyHashTable:get 18
# DEBUG:MyHashTable:Looking for key 18 in bucket 59
# DEBUG:MyHashTable:Found correct bucket 59 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=0)
# DEBUG:MyHashTable:get 18: 18 from bucket 59
# DEBUG:MyHashTable:get 22
# DEBUG:MyHashTable:Looking for key 22 in bucket 61
# DEBUG:MyHashTable:Found correct bucket 61 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=0)
# DEBUG:MyHashTable:get 22: 22 from bucket 61
# DEBUG:MyHashTable:get 6
# DEBUG:MyHashTable:Looking for key 6 in bucket 65
# DEBUG:MyHashTable:Found correct bucket 65 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=0)
# DEBUG:MyHashTable:get 6: 6 from bucket 65
# DEBUG:MyHashTable:get 0
# DEBUG:MyHashTable:Looking for key 0 in bucket 73
# DEBUG:MyHashTable:Found correct bucket 73 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=0)
# DEBUG:MyHashTable:get 0: 0 from bucket 73
# DEBUG:MyHashTable:get 13
# DEBUG:MyHashTable:Looking for key 13 in bucket 76
# DEBUG:MyHashTable:Found correct bucket 76 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=0)
# DEBUG:MyHashTable:get 13: 13 from bucket 76
# DEBUG:MyHashTable:get 19
# DEBUG:MyHashTable:Looking for key 19 in bucket 77
# DEBUG:MyHashTable:Found correct bucket 77 after 0 collisions
# DEBUG:MyHashTable:collision report: collisionLog(n_buckets=100, len=24, collisions=0)

# %%
fig, ax = plt.subplots()
for i, n_buckets in enumerate(n_bucketss):
    ax.plot(results[i][:, 0], results[i][:, 1], label=f"n_buckets={n_buckets}")
ax.legend()
ax.set_xlabel("Utilization Factor")
ax.set_ylabel("Average Number of Collisions per Get")
